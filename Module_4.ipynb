# %% [markdown]
# <a href="https://colab.research.google.com/github/0257chaitanyaprasad/python-new/blob/module-4/Module_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Pyplot
import matplotlib.pyplot as plt
import numpy as np
xpoints = np.array([0,10])
ypoints = np.array([0,8])
plt.plot(xpoints, ypoints)
plt.show()

# %%
# Bar graph
import matplotlib.pyplot as plt
import numpy as np
x = np.array(["CLAD1001", "CSEN1001", "LANG1011", "MATH1001","MATH1011","MECH1021","PHYS1001","VEDC1001"])
y = np.array([94,94,78,93,95,92,75,93])
plt.bar(x,y)
plt.show()

# %%
# Pie chart
import matplotlib.pyplot as plt
import numpy as np
y = np.array([94,94,78,93,95,92,75,93])
mylabels = ["CLAD1001", "CSEN1001", "LANG1011", "MATH1001","MATH1011","MECH1021","PHYS1001","VEDC1001"]
plt.pie(y, labels = mylabels)
plt.show()

# %%
#Plotting without lines
import matplotlib.pyplot as plt
import numpy as np
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y)
plt.show()

# %%
# 
import matplotlib.pyplot as plt
import numpy as np
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])
plt.subplot(1, 2, 1)
plt.plot(x,y)
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)

plt.show()

# %%
# Create Labels for a Plot
import numpy as np
import matplotlib.pyplot as plt
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([40, 50, 60, 70, 80, 90, 100, 110, 120, 130])
plt.plot(x, y)
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")
plt.show()

# %%
# Linestyle
import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array([3, 8, 1, 10])
plt.plot(ypoints, linestyle = 'dotted')
plt.show()

# %%
# Labels for a Plot
import matplotlib.pyplot as plt
import numpy as np
xpoints = np.array(["CLAD1001", "CSEN1001", "LANG1011", "MATH1001","MATH1011","MECH1021","PHYS1001","VEDC1001"])
ypoints = np.array([94,94,78,93,95,92,75,93])

plt.plot(xpoints, ypoints)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array(["CLAD1001", "CSEN1001", "LANG1011", "MATH1001","MATH1011","MECH1021","PHYS1001","VEDC1001"])
y = np.array([94,94,78,93,95,92,75,93])
plt.plot(x, y)
plt.title("Sem 1 marks")
plt.xlabel("Subjects")
plt.ylabel("Marks")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.array(["CLAD1001", "CSEN1001", "LANG1011", "MATH1001","MATH1011","MECH1021","PHYS1001","VEDC1001"])
y = np.array([94,94,78,93,95,92,75,93])
plt.title("Sem 1 result")
plt.xlabel("Subject")
plt.ylabel("Marks")
plt.plot(x, y)
plt.grid()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.array(["CLAD1001", "CSEN1001", "LANG1011", "MATH1001","MATH1011","MECH1021","PHYS1001","VEDC1001"])
y = np.array([94,94,78,93,95,92,75,93])
plt.title("Sem 1 result")
plt.xlabel("Subject")
plt.ylabel("Marks")
plt.plot(x, y)
plt.grid(axis = 'x')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.array(["CLAD1001", "CSEN1001", "LANG1011", "MATH1001","MATH1011","MECH1021","PHYS1001","VEDC1001"])
y = np.array([94,94,78,93,95,92,75,93])
plt.title("Sem 1 result")
plt.xlabel("Subject")
plt.ylabel("Marks")
plt.plot(x, y)
plt.grid(axis = 'y')
plt.show()

# %%
import matplotlib.pyplot as plt
figure, axes = plt.subplots()
Drawing_colored_circle = plt.Circle(( 0.6 , 0.6 ), 0.2 )
axes.set_aspect( 1 )
axes.add_artist( Drawing_colored_circle )
plt.title( 'Colored Circle' )
plt.show()

# %%
import matplotlib.pyplot as plt
plt.scatter(0, 0, s=10000,
facecolors='red', edgecolors='green' )
plt.xlim(1,6)
plt.ylim(1, 3)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array(["CLAD1001", "CSEN1001", "LANG1011", "MATH1001","MATH1011","MECH1021","PHYS1001","VEDC1001"])
y = np.array([94,94,78,93,95,92,75,93])
plt.barh(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array(["CLAD1001", "CSEN1001", "LANG1011", "MATH1001","MATH1011","MECH1021","PHYS1001","VEDC1001"])
y = np.array([94,94,78,93,95,92,75,93])
plt.bar(x, y, color = "green")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array(["CLAD1001", "CSEN1001", "LANG1011", "MATH1001","MATH1011","MECH1021","PHYS1001","VEDC1001"])
y = np.array([94,94,78,93,95,92,75,93])
plt.bar(x, y, width = 0.5)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array(["CLAD1001", "CSEN1001", "LANG1011", "MATH1001","MATH1011","MECH1021","PHYS1001","VEDC1001"])
y = np.array([94,94,78,93,95,92,75,93])
plt.barh(x, y, height = 0.5)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.normal(60,50,40)
plt.hist(x)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints = np.array([1,6])
ypoints = np.array([3,5])
plt.plot(xpoints, ypoints, 'o')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints = np.array([2,4,6,8,10])
ypoints = np.array([3,5,7,9,11])
plt.plot(xpoints, ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array([3, 8, 1, 10, 5, 7, 9 ,20])
plt.plot(ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([94,94,78,93,95,92,75,93])

plt.plot(ypoints, marker = 'o')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([94,94,78,93,95,92,75,93])

plt.plot(ypoints, marker = '*')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array([94,94,78,93,95,92,75,93])
plt.plot(ypoints, 'o:r')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
y = np.array([94,94,78,93,95,92,75,93])
plt.pie(y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
y = np.array([100, 93, 95, 96])
mylabels = ["Dhoni", "Rayudu", "Gaikwad", "Jadeja"]
myexplode = [0.2, 0.2, 0.2, 0.2]
plt.pie(y, labels = mylabels, explode = myexplode)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
y = np.array([100, 93, 95, 96])
mylabels = ["Dhoni", "Rayudu", "Gaikwad", "Jadeja"]
myexplode = [0.2, 0.2, 0.2, 0.2]
plt.pie(y, labels = mylabels, explode = myexplode, shadow = True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([100, 93, 95, 96])
mylabels = ["Dhoni", "Rayudu", "Gaikwad", "Jadeja"]
mycolors = ["r", "y", "b", "g"]

plt.pie(y, labels = mylabels, colors = mycolors)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
y = np.array([94,94,78,93,95,92,75,93])
mylabels = ["CLAD1001", "CSEN1001", "LANG1011", "MATH1001","MATH1011","MECH1021","PHYS1001","VEDC1001"]
plt.pie(y, labels = mylabels)
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y)

x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array(["red","green","blue","yellow","pink","black","orange","purple","beige","brown","gray","cyan","magenta"])

plt.scatter(x, y, c=colors)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x, y, c=colors, cmap='viridis')

plt.colorbar()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([1, 2, 3, 4, 5, 6])
y = np.array([3, 8, 1, 10, 12, 14])

plt.subplot(2, 1, 1)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 1, 2)
plt.plot(x,y)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array([2,3,5,8,6,10,25])
plt.plot(ypoints, linewidth = '15.0')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
y1 = np.array([])
y2 = np.array([2,3,1,8,4,9,12])
plt.plot(y1)
plt.plot(y2)
plt.show()
